# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib notebook

# %%
sns.set(context='notebook')
plt.tight_layout()

# %%
temp = pd.read_csv('data/1429_1.csv')

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34660 entries, 0 to 34659
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    34660 non-null  object
#  1   name                  27900 non-null  object
#  2   asins                 34658 non-null  object
#  3   brand                 34660 non-null  object
#  4   categories            34660 non-null  object
#  5   keys                  34660 non-null  object
#  6   manufacturer          34660 non-null  object
#  7   reviews.date          34621 non-null  object
#  8   reviews.dateAdded     24039 non-null  object
#  9   reviews.dateSeen      34660 non-null  object
#  10  reviews.didPurchase   1 non-null      object
#  11  reviews.doRecommend   34066 non-null  object
#  12  reviews.id            1 non-null      float64
#  13  reviews.numHelpful    34131 non-null  float64
#  14  reviews.rating        34627 non-null  float64
# ...

# %%
temp.isna().sum()
# Out:
# id                          0
# name                     6760
# asins                       2
# brand                       0
# categories                  0
# keys                        0
# manufacturer                0
# reviews.date               39
# reviews.dateAdded       10621
# reviews.dateSeen            0
# reviews.didPurchase     34659
# reviews.doRecommend       594
# reviews.id              34659
# reviews.numHelpful        529
# reviews.rating             33
# reviews.sourceURLs          0
# reviews.text                1
# reviews.title               5
# reviews.userCity        34660
# reviews.userProvince    34660
# reviews.username            2
# dtype: int64

# %%
temp.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# ...

# %%
temp.manufacturer.unique()
# Out:
# array(['Amazon', 'Amazon Digital Services, Inc'], dtype=object)

# %%
temp['reviews.didPurchase'].notna().sum()
# Out:
# 1

# %%
temp.columns
# Out:
# Index(['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer',
#        'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen',
#        'reviews.didPurchase', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username'],
#       dtype='object')

# %%
df = pd.DataFrame(temp[['id', 'name', 'brand', 'categories', 'reviews.doRecommend', 'reviews.numHelpful', 'reviews.rating', 'reviews.title']])

# %%
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#     brand                                         categories  \
# 0  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#   reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# 0                True                 0.0             5.0
# ...

# %%
df.set_index('id', inplace=True)

# %%
df.head()
# Out:
#                                                                    name  \
# id
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#                        brand  \
# id
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
#
#                                                              categories  \
# id
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# ...

# %%
df.rename(columns={
    'reviews.doRecommend' : 'recommend',
    'reviews.numHelpful' : 'helpful',
    'reviews.rating' : 'rating',
    'reviews.title' : 'review_title'
}, inplace=True)

# %%
df.head()
# Out:
#                                                                    name  \
# id
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#                        brand  \
# id
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
#
#                                                              categories  \
# id
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# ...

# %%
len(df.name.unique())
# Out:
# 49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34660 entries, AVqkIhwDv8e3D1O-lebb to AVpfiBlyLJeJML43-4Tp
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          27900 non-null  object
#  1   brand         34660 non-null  object
#  2   categories    34660 non-null  object
#  3   recommend     34066 non-null  object
#  4   helpful       34131 non-null  float64
#  5   rating        34627 non-null  float64
#  6   review_title  34655 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#             helpful        rating
# count  34131.000000  34627.000000
# mean       0.630248      4.584573
# std       13.215775      0.735653
# min        0.000000      1.000000
# 25%        0.000000      4.000000
# 50%        0.000000      5.000000
# 75%        0.000000      5.000000
# max      814.000000      5.000000

# %%
df.isna().sum()
# Out:
# name            6760
# brand              0
# categories         0
# recommend        594
# helpful          529
# rating            33
# review_title       5
# dtype: int64

# %%
df[df['rating'].isna()]
# Out:
#                                                                    name  \
# id
# AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# AVpfBEWcilAPnD_xTGb7           Kindle Keyboard,,,\r\nKindle Keyboard,,,
# AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVpfBEWcilAPnD_xTGb7  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# ...

# %%
df['rating'].dropna()
# Out:
# id
# AVqkIhwDv8e3D1O-lebb    5.0
# AVqkIhwDv8e3D1O-lebb    5.0
# AVqkIhwDv8e3D1O-lebb    5.0
# AVqkIhwDv8e3D1O-lebb    4.0
# AVqkIhwDv8e3D1O-lebb    5.0
#                        ...
# AVpfiBlyLJeJML43-4Tp    3.0
# AVpfiBlyLJeJML43-4Tp    1.0
# AVpfiBlyLJeJML43-4Tp    1.0
# AVpfiBlyLJeJML43-4Tp    1.0
# AVpfiBlyLJeJML43-4Tp    1.0
# Name: rating, Length: 34627, dtype: float64

# %%
df.head()
# Out:
#                                                                    name  \
# id
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#                        brand  \
# id
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
# AVqkIhwDv8e3D1O-lebb  Amazon
#
#                                                              categories  \
# id
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# AVqkIhwDv8e3D1O-lebb  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# ...

# %%
good_rating = df[(df['rating'] > 0) & (df['helpful'] > 0.6)]

# %%
good_rating
# Out:
#                                                                    name  \
# id
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# ...                                                                 ...
# AV1YE_muvKc47QAVgpwE                                                NaN
# AVpf_znpilAPnD_xlvAF                                                NaN
# AVpf_znpilAPnD_xlvAF                                                NaN
# AVpf_znpilAPnD_xlvAF                                                NaN
# AVpf_znpilAPnD_xlvAF                                                NaN
#
#                                              brand  \
# id
# ...

# %%
#sns.jointplot("helpful", "rating", data=good_rating, kind="kde", color="g")
plt.figure(figsize=(15,10))
sns.distplot(good_rating['rating'])

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='brand', y='rating', data=good_rating)
